# %%
# !mamba install pandas
# !mamba install seaborn
# !mamba install matplotlib
# !mamba install scikit-learn

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# Out:
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.333 seconds
# All requested packages already installed.
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 0.7390000000001165 seconds
# All requested packages already installed.
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 0.662 seconds
# All requested packages already installed.
# mambajs 0.21.1
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, seaborn, scikit-learn
# ...

# %%
df = pd.read_csv("H-MERIDIANHEALTH.csv")
print(df.head())
# Out:
#   patient_id hospital_id hospital_location_type  hospital_size_beds  \
# 0   PT007060      HCA016                  Urban                 466
# 1   PT008060      HCA018               Suburban                 313
# 2   PT007196      HCA007                  Urban                 342
# 3   PT000192      HCA006               Suburban                 288
# 4   PT003334      HCA044                  Urban                 336
#
#   admission_date admission_type primary_diagnosis  comorbidity_count  \
# 0     2023-01-01         Urgent        Orthopedic                  2
# 1     2023-01-01       Elective       Respiratory                  2
# 2     2023-01-01       Elective       Respiratory                  4
# 3     2023-01-01      Emergency       Respiratory                  1
# 4     2023-01-01      Emergency    Cardiovascular                  3
#
#    patient_age  length_of_stay_days     discharge_disposition  \
# 0           78                    5  Skilled Nursing Facility
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   patient_id                           10000 non-null  str
#  1   hospital_id                          10000 non-null  str
#  2   hospital_location_type               10000 non-null  str
#  3   hospital_size_beds                   10000 non-null  int64
#  4   admission_date                       10000 non-null  str
#  5   admission_type                       10000 non-null  str
#  6   primary_diagnosis                    10000 non-null  str
#  7   comorbidity_count                    10000 non-null  int64
#  8   patient_age                          10000 non-null  int64
#  9   length_of_stay_days                  10000 non-null  int64
#  10  discharge_disposition                10000 non-null  str
# ...

# %%
df.isnull().sum()
# Out:
# patient_id                                0
# hospital_id                               0
# hospital_location_type                    0
# hospital_size_beds                        0
# admission_date                            0
# admission_type                            0
# primary_diagnosis                         0
# comorbidity_count                         0
# patient_age                               0
# length_of_stay_days                       0
# discharge_disposition                     0
# follow_up_scheduled                       0
# post_discharge_call_made                  0
# patient_education_provided                0
# medication_reconciliation_completed       0
# social_determinants_risk_score            0
# insurance_type                            0
# ed_visits_past_year                       0
# readmission_30day                         0
# readmission_reason                     5451
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['patient_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df['readmission_reason'] = (df['readmission_reason'].fillna('Not Applicable'))

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   patient_id                           10000 non-null  str
#  1   hospital_id                          10000 non-null  str
#  2   hospital_location_type               10000 non-null  str
#  3   hospital_size_beds                   10000 non-null  int64
#  4   admission_date                       10000 non-null  str
#  5   admission_type                       10000 non-null  str
#  6   primary_diagnosis                    10000 non-null  str
#  7   comorbidity_count                    10000 non-null  int64
#  8   patient_age                          10000 non-null  int64
#  9   length_of_stay_days                  10000 non-null  int64
#  10  discharge_disposition                10000 non-null  str
# ...

# %%
validation_report = pd.DataFrame({
    'Check': [
        'Duplicate Rows',
        'Duplicate Patient IDs',
        'Null Admission Dates',
        'Invalid Length of Stay',
        'Invalid Hospital Beds'
    ],
    'Count': [
        df.duplicated().sum(),
        df['patient_id'].duplicated().sum(),
        df['admission_date'].isna().sum(),
        (df['length_of_stay_days'] <= 0).sum(),
        (df['hospital_size_beds'] <= 0).sum()
    ]
})
validation_report
# Out:
#                     Check  Count
# 0          Duplicate Rows      0
# 1   Duplicate Patient IDs      0
# 2    Null Admission Dates      0
# 3  Invalid Length of Stay      0
# 4   Invalid Hospital Beds      0

# %%
df.to_csv("H-MERIDIANHEALTH_cleaned.csv", index=False)
print("File exported")
# Out:
# File exported
